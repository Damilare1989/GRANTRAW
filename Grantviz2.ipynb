# %%
import numpy as np
import pandas as pd

# %%
file_name1 = 'Data Aisha 2.xlsx'
file_name2 = 'grant spreadsheet emma 2.xlsx'
file_name3 = 'grant spreadsheet kemi 2.xlsx'
file_name4 = 'grant spreadsheet.xlsx'

# %%
data1 = pd.read_excel(file_name1)
data2 = pd.read_excel(file_name2)
data3 = pd.read_excel(file_name3)
data4 = pd.read_excel(file_name4)

# %%
len(data1)
# Out:
# 1308

# %%
data1.isna().sum()
# Out:
# Unnamed: 0     1307
# Unnamed: 1        0
# Unnamed: 2      866
# Unnamed: 3        0
# Unnamed: 4      325
# Unnamed: 5        2
# Unnamed: 6      954
# Unnamed: 7      953
# Unnamed: 8      820
# Unnamed: 9        9
# Unnamed: 10     853
# Unnamed: 11    1147
# Unnamed: 12     969
# Unnamed: 13    1167
# Unnamed: 14    1140
# Unnamed: 15    1151
# Unnamed: 16    1132
# Unnamed: 17    1139
# Unnamed: 18    1296
# dtype: int64

# %%
len(data2)
# Out:
# 1308

# %%
data2.isna().sum()
# Out:
# Unnamed: 0        0
# Unnamed: 1      807
# Unnamed: 2        0
# Unnamed: 3      321
# Unnamed: 4        2
# Unnamed: 5      858
# Unnamed: 6      856
# Unnamed: 7      743
# Unnamed: 8        5
# Unnamed: 9      771
# Unnamed: 10    1036
# Unnamed: 11     873
# Unnamed: 12    1032
# Unnamed: 13    1038
# Unnamed: 14    1048
# Unnamed: 15    1032
# Unnamed: 16    1042
# Unnamed: 17    1140
# dtype: int64

# %%
len(data3)
# Out:
# 1308

# %%
data3.isna().sum()
# Out:
# Unnamed: 0     1307
# Unnamed: 1        0
# Unnamed: 2      822
# Unnamed: 3        0
# Unnamed: 4      325
# Unnamed: 5        2
# Unnamed: 6      901
# Unnamed: 7      900
# Unnamed: 8      766
# Unnamed: 9        9
# Unnamed: 10     797
# Unnamed: 11    1093
# Unnamed: 12     917
# Unnamed: 13    1102
# Unnamed: 14    1087
# Unnamed: 15    1097
# Unnamed: 16    1081
# Unnamed: 17    1088
# Unnamed: 18    1284
# dtype: int64

# %%
len(data4)
# Out:
# 1323

# %%
data4.isna().sum()
# Out:
# Unnamed: 0     1322
# Unnamed: 1        0
# Unnamed: 2      849
# Unnamed: 3        0
# Unnamed: 4      324
# Unnamed: 5        2
# Unnamed: 6      918
# Unnamed: 7      916
# Unnamed: 8      791
# Unnamed: 9        7
# Unnamed: 10     825
# Unnamed: 11    1114
# Unnamed: 12     937
# Unnamed: 13    1112
# Unnamed: 14    1120
# Unnamed: 15    1129
# Unnamed: 16    1113
# Unnamed: 17    1120
# Unnamed: 18    1232
# dtype: int64

# %%
data1.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3   Unnamed: 4  Unnamed: 5  \
# 0         NaN    FORM NO      TITLE  FIRST NAME  MIDDLE NAME   LAST NAME
# 1         NaN          1        Mrs     Abidemi       Ayinke      Dosumu
# 2         NaN          2        Mrs     Adetoro          NaN      Bayewu
# 3         NaN          3        NaN     Risikat    Remilekun     Solanke
# 4         NaN          4        NaN      Ismail       Abiola  Olarenwaju
#
#       Unnamed: 6    Unnamed: 7     Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# 0  DATE OF BIRTH  HOME ADDRESS     OCCUPATION    PHONE NO        BANK
# 1            NaN           NaN         Trader  8023763598         UBA
# 2            NaN           NaN  Civil Servant  8029569059         GTB
# 3            NaN           NaN            NaN  8088884002         NaN
# 4            NaN           NaN            NaN  8188267384         NaN
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14        Unnamed: 15  \
# ...

# %%
data2.head()
# Out:
#   Unnamed: 0 Unnamed: 1  Unnamed: 2   Unnamed: 3  Unnamed: 4  \
# 0    FORM NO      TITLE  FIRST NAME  MIDDLE NAME   LAST NAME
# 1          1        Mrs     Abidemi       Ayinke      Dosumu
# 2          2        Mrs     Adetoro          NaN      Bayewu
# 3          3        Mrs     Risikat    Remilekun     Solanke
# 4          4         Mr      Ismail       Abiola  Olarenwaju
#
#             Unnamed: 5             Unnamed: 6     Unnamed: 7  Unnamed: 8  \
# 0        DATE OF BIRTH           HOME ADDRESS     OCCUPATION    PHONE NO
# 1  1967-03-04 00:00:00  53 iyun road surulere         Trader  8023763598
# 2                  NaN                    NaN  Civil Servant  8029569059
# 3           19/04/1964        27 onitolo road         Trader  8088884002
# 4           17/10/1979    43 Durojaiye street         trader  8188267384
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0       BANK   ALLOTMENT  ACCOUNT NO
# 1        UBA      100000  2059795764
# 2        GTB         NaN         NaN
# ...

# %%
data3.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3   Unnamed: 4  Unnamed: 5  \
# 0        NaN    FORM NO      TITLE  FIRST NAME  MIDDLE NAME   LAST NAME
# 1        NaN          1        Mrs     Abidemi       Ayinke      Dosumu
# 2        NaN          2        Mrs     Adetoro          NaN      Bayewu
# 3        NaN          3        NaN     Risikat    Remilekun     Solanke
# 4        NaN          4        NaN      Ismail       Abiola  Olarenwaju
#
#       Unnamed: 6    Unnamed: 7     Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# 0  DATE OF BIRTH  HOME ADDRESS     OCCUPATION    PHONE NO        BANK
# 1            NaN           NaN         Trader  8023763598         UBA
# 2            NaN           NaN  Civil Servant  8029569059         GTB
# 3            NaN           NaN            NaN  8088884002         NaN
# 4            NaN           NaN            NaN  8188267384         NaN
#
#   Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14        Unnamed: 15  \
# ...

# %%
data4.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2  Unnamed: 3   Unnamed: 4  Unnamed: 5  \
# 0        NaN    FORM NO      TITLE  FIRST NAME  MIDDLE NAME   LAST NAME
# 1        NaN          1        Mrs     Abidemi       Ayinke      Dosumu
# 2        NaN          2        Mrs     Adetoro          NaN      Bayewu
# 3        NaN          3        NaN     Risikat    Remilekun     Solanke
# 4        NaN          4        NaN      Ismail       Abiola  Olarenwaju
#
#             Unnamed: 6             Unnamed: 7     Unnamed: 8  Unnamed: 9  \
# 0        DATE OF BIRTH           HOME ADDRESS     OCCUPATION    PHONE NO
# 1  1967-03-04 00:00:00  53 iyun road surulere         Trader  8023763598
# 2                  NaN                    NaN  Civil Servant  8029569059
# 3                  NaN                    NaN            NaN  8088884002
# 4                  NaN                    NaN            NaN  8188267384
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0        BANK   ALLOTMENT  ACCOUNT NO
# ...

# %%
data1.drop(['Unnamed: 0'], axis = 1, inplace = True)
data3.drop(['Unnamed: 0'], axis = 1, inplace = True)
data4.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
data1.rename(columns = {'Unnamed: 1':'FORM NO', 'Unnamed: 2': 'TITLE', 'Unnamed: 3': 'FIRST NAME', 
                        'Unnamed: 4': 'MIDDLE NAME', 'Unnamed: 5': 'LAST NAME', 'Unnamed: 6': 'DATE OF BIRTH', 
                        'Unnamed: 7': 'HOME ADDRESS', 'Unnamed: 8': 'OCCUPATION', 'Unnamed: 9': 'PHONE NO',
                        'Unnamed: 10': 'BANK', 'Unnamed: 11': 'ALLOTMENT', 'Unnamed: 12': 'ACCOUNT NO', 
                        'Unnamed: 13': 'REMARK', 'Unnamed: 14': 'SECTOR', 'Unnamed: 15': 'YEARS IN BUSINESS', 
                        'Unnamed: 16': 'SCORE', 'Unnamed: 17': 'AMOUNT', 'Unnamed: 18': 'DECLINE/GRANT' }, inplace = True)

# %%
data2.rename(columns = {'Unnamed: 0':'FORM NO', 'Unnamed: 1': 'TITLE', 'Unnamed: 2': 'FIRST NAME', 
                       'Unnamed: 3': 'MIDDLE NAME', 'Unnamed: 4': 'LAST NAME', 'Unnamed: 5': 'DATE OF BIRTH', 
                        'Unnamed: 6': 'HOME ADDRESS', 'Unnamed: 7': 'OCCUPATION', 'Unnamed: 8': 'PHONE NO',
                        'Unnamed: 9': 'BANK', 'Unnamed: 10': 'ALLOTMENT', 'Unnamed: 11': 'ACCOUNT NO', 
                        'Unnamed: 12': 'REMARK', 'Unnamed: 13': 'SECTOR', 'Unnamed: 14': 'YEARS IN BUSINESS', 
                        'Unnamed: 15': 'SCORE', 'Unnamed: 16': 'AMOUNT', 'Unnamed: 17': 'DECLINE/GRANT' }, inplace = True)

# %%
data3.rename(columns = {'Unnamed: 1':'FORM NO', 'Unnamed: 2': 'TITLE', 'Unnamed: 3': 'FIRST NAME', 
                        'Unnamed: 4': 'MIDDLE NAME', 'Unnamed: 5': 'LAST NAME', 'Unnamed: 6': 'DATE OF BIRTH', 
                       'Unnamed: 7': 'HOME ADDRESS', 'Unnamed: 8': 'OCCUPATION', 'Unnamed: 9': 'PHONE NO',
                        'Unnamed: 10': 'BANK', 'Unnamed: 11': 'ALLOTMENT', 'Unnamed: 12': 'ACCOUNT NO', 
                       'Unnamed: 13': 'REMARK', 'Unnamed: 14': 'SECTOR', 'Unnamed: 15': 'YEARS IN BUSINESS', 
                       'Unnamed: 16': 'SCORE', 'Unnamed: 17': 'AMOUNT', 'Unnamed: 18': 'DECLINE/GRANT' }, inplace = True)

# %%
data4.rename(columns = {'Unnamed: 1':'FORM NO', 'Unnamed: 2': 'TITLE', 'Unnamed: 3': 'FIRST NAME', 
                        'Unnamed: 4': 'MIDDLE NAME', 'Unnamed: 5': 'LAST NAME', 'Unnamed: 6': 'DATE OF BIRTH', 
                       'Unnamed: 7': 'HOME ADDRESS', 'Unnamed: 8': 'OCCUPATION', 'Unnamed: 9': 'PHONE NO',
                        'Unnamed: 10': 'BANK', 'Unnamed: 11': 'ALLOTMENT', 'Unnamed: 12': 'ACCOUNT NO', 
                       'Unnamed: 13': 'REMARK', 'Unnamed: 14': 'SECTOR', 'Unnamed: 15': 'YEARS IN BUSINESS', 
                       'Unnamed: 16': 'SCORE', 'Unnamed: 17': 'AMOUNT', 'Unnamed: 18': 'DECLINE/GRANT' }, inplace = True)

# %%
data1.drop(data1.index[0], inplace = True)
data2.drop(data2.index[0], inplace = True)
data3.drop(data3.index[0], inplace = True)
data4.drop(data4.index[0], inplace = True)

# %%
data1.head()
# Out:
#   FORM NO TITLE FIRST NAME MIDDLE NAME   LAST NAME DATE OF BIRTH HOME ADDRESS  \
# 1       1   Mrs    Abidemi      Ayinke      Dosumu           NaN          NaN
# 2       2   Mrs    Adetoro         NaN      Bayewu           NaN          NaN
# 3       3   NaN    Risikat   Remilekun     Solanke           NaN          NaN
# 4       4   NaN     Ismail      Abiola  Olarenwaju           NaN          NaN
# 5       5   NaN    Mudirat  Oluwatoyin        Alao           NaN          NaN
#
#       OCCUPATION    PHONE NO BANK ALLOTMENT ACCOUNT NO REMARK SECTOR  \
# 1         Trader  8023763598  UBA       NaN        NaN    NaN    NaN
# 2  Civil Servant  8029569059  GTB       NaN        NaN    NaN    NaN
# 3            NaN  8088884002  NaN       NaN        NaN    NaN    NaN
# 4            NaN  8188267384  NaN       NaN        NaN    NaN    NaN
# 5            NaN  8135988651  NaN       NaN        NaN    NaN    NaN
#
#   YEARS IN BUSINESS SCORE AMOUNT DECLINE/GRANT
# ...

# %%
data2.head()
# Out:
#   FORM NO TITLE FIRST NAME MIDDLE NAME   LAST NAME        DATE OF BIRTH  \
# 1       1   Mrs    Abidemi      Ayinke      Dosumu  1967-03-04 00:00:00
# 2       2   Mrs    Adetoro         NaN      Bayewu                  NaN
# 3       3   Mrs    Risikat   Remilekun     Solanke           19/04/1964
# 4       4    Mr     Ismail      Abiola  Olarenwaju           17/10/1979
# 5       5   NaN    Mudirat  Oluwatoyin        Alao                  NaN
#
#             HOME ADDRESS     OCCUPATION    PHONE NO    BANK ALLOTMENT  \
# 1  53 iyun road surulere         Trader  8023763598     UBA    100000
# 2                    NaN  Civil Servant  8029569059     GTB       NaN
# 3        27 onitolo road         Trader  8088884002     gtb    100000
# 4    43 Durojaiye street         trader  8188267384  Access     30000
# 5                    NaN            NaN  8135988651     NaN       NaN
#
#    ACCOUNT NO                                             REMARK  \
# ...

# %%
data3.head()
# Out:
#   FORM NO TITLE FIRST NAME MIDDLE NAME   LAST NAME DATE OF BIRTH  \
# 1       1   Mrs    Abidemi      Ayinke      Dosumu           NaN
# 2       2   Mrs    Adetoro         NaN      Bayewu           NaN
# 3       3   NaN    Risikat   Remilekun     Solanke           NaN
# 4       4   NaN     Ismail      Abiola  Olarenwaju           NaN
# 5       5   mrs    Mudirat  Oluwatoyin        Alao     18/3/1957
#
#                HOME ADDRESS     OCCUPATION    PHONE NO       BANK ALLOTMENT  \
# 1                       NaN         Trader  8023763598        UBA       NaN
# 2                       NaN  Civil Servant  8029569059        GTB       NaN
# 3                       NaN            NaN  8088884002        NaN       NaN
# 4                       NaN            NaN  8188267384        NaN       NaN
# 5  20 ajeke awowunmi street         Trader  8135988651  FirstBank     70000
#
#    ACCOUNT NO           REMARK            SECTOR YEARS IN BUSINESS SCORE  \
# ...

# %%
data4.head()
# Out:
#   FORM NO TITLE FIRST NAME MIDDLE NAME   LAST NAME        DATE OF BIRTH  \
# 1       1   Mrs    Abidemi      Ayinke      Dosumu  1967-03-04 00:00:00
# 2       2   Mrs    Adetoro         NaN      Bayewu                  NaN
# 3       3   NaN    Risikat   Remilekun     Solanke                  NaN
# 4       4   NaN     Ismail      Abiola  Olarenwaju                  NaN
# 5       5   NaN    Mudirat  Oluwatoyin        Alao                  NaN
#
#             HOME ADDRESS     OCCUPATION    PHONE NO BANK ALLOTMENT  \
# 1  53 iyun road surulere         Trader  8023763598  UBA    100000
# 2                    NaN  Civil Servant  8029569059  GTB       NaN
# 3                    NaN            NaN  8088884002  NaN       NaN
# 4                    NaN            NaN  8188267384  NaN       NaN
# 5                    NaN            NaN  8135988651  NaN       NaN
#
#    ACCOUNT NO                                             REMARK      SECTOR  \
# ...

# %%
data1.update(data2, join = 'left', overwrite = True)
data1.update(data3, join = 'left', overwrite = True)

# %%
data = data1.copy()

# %%
data.isna().sum()
# Out:
# FORM NO                 0
# TITLE                 578
# FIRST NAME              0
# MIDDLE NAME           317
# LAST NAME               2
# DATE OF BIRTH         597
# HOME ADDRESS          595
# OCCUPATION            515
# PHONE NO                5
# BANK                  532
# ALLOTMENT             725
# ACCOUNT NO            603
# REMARK                771
# SECTOR                736
# YEARS IN BUSINESS     769
# SCORE                 724
# AMOUNT                744
# DECLINE/GRANT        1128
# dtype: int64

# %%
data.update(data4, join = 'left', overwrite = True)

# %%
full_data = data.copy()

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
#pd.reset_option('display.max_rows')
#pd.reset_option('display.max_columns')

# %%
#export_csv = full_data.to_csv(r'C:\Users\GETHSEMAN\Desktop\GBAJA2\complete_dataframe.csv', 
#index = None, header=True)

# %% [markdown]
# **INFERENCES AND VISUALIIZATION

# %%
#The total number of applicants is:
len(full_data)
# Out:
# 1307

# %%
#The variables that were captured in the data are:
full_data.columns
# Out:
# Index(['FORM NO', 'TITLE', 'FIRST NAME', 'MIDDLE NAME', 'LAST NAME',
#        'DATE OF BIRTH', 'HOME ADDRESS', 'OCCUPATION', 'PHONE NO', 'BANK',
#        'ALLOTMENT', 'ACCOUNT NO', 'REMARK', 'SECTOR', 'YEARS IN BUSINESS',
#        'SCORE', 'AMOUNT', 'DECLINE/GRANT'],
#       dtype='object')

# %%
full_data[full_data['FIRST NAME'] ==      'Rabiat']
# Out:
#     FORM NO   TITLE FIRST NAME MIDDLE NAME LAST NAME        DATE OF BIRTH  \
# 38       38  Alhaja     Rabiat          A.    Lawson                  NaN
# 274     304     NaN     Rabiat       Ajobi    Quadri                  NaN
# 297     341     Mrs     Rabiat       Alake   Ibrahim  1934-12-22 00:00:00
# 740     858     Mrs     Rabiat       Ejide     Saibu  1976-08-15 00:00:00
#
#                                    HOME ADDRESS OCCUPATION    PHONE NO   BANK  \
# 38             2 onatoro lane barracks surulere     Trader  8023007540    UBA
# 274                                         NaN        NaN  8178662953    NaN
# 297  block 11 flat 27 rabiatu thompson surulere     trader  8027543982  union
# 740                           44 akerele street   Business  8027480094    UBA
#
#     ALLOTMENT  ACCOUNT NO                                             REMARK  \
# 38      60000  2059782223                              to boost my business
# ...

# %% [markdown]
# FORM NO, TITLE, FIRST_NAME, MIDDLE_NAME, LAST NAME, DATE OF BIRTH, HOME ADDRESS
# OCCUPATION, PHONE NO, BANK, ALLOTMENT, ACCOUNT NUMBER, REMARK, SECTOR,
# YEARS IN BUSINESS, SCORE, AMOUNT, DECLINE/GRANT

# %%
#The result below show the predictors and the total number of missing values
#for each of the variables that were captured in the dataset
full_data.isna().sum()
# Out:
# FORM NO                 0
# TITLE                 417
# FIRST NAME              0
# MIDDLE NAME            85
# LAST NAME               0
# DATE OF BIRTH         447
# HOME ADDRESS          444
# OCCUPATION            350
# PHONE NO                0
# BANK                  370
# ALLOTMENT             605
# ACCOUNT NO            449
# REMARK                648
# SECTOR                618
# YEARS IN BUSINESS     649
# SCORE                 602
# AMOUNT                628
# DECLINE/GRANT        1054
# dtype: int64

# %% [markdown]
# Let's calculate the total number of applicants whose application was granted.
# The Words "yes" with 4 different literals and "grant" were used to this effect...
# so we calculate all the records with these expressions

# %%
full_data['DECLINE/GRANT'].unique()
# Out:
# array(['yes', nan, 'Yes', 'yes ', 'grant', 'decline', '`yes', 'no '],
#       dtype=object)

# %%
granted1 = full_data.loc[full_data['DECLINE/GRANT'] == 'Yes']
granted1
# Out:
#     FORM NO TITLE FIRST NAME MIDDLE NAME   LAST NAME        DATE OF BIRTH  \
# 4         4    Mr     Ismail      Abiola  Olarenwaju           17/10/1979
# 426     500   Mrs     Hammed    Suliamon     Ajibade  1960-01-10 00:00:00
#
#                                HOME ADDRESS    OCCUPATION    PHONE NO  \
# 4                       43 Durojaiye street        trader  8188267384
# 426  blk 9 flat 2 rabiatu thompson crescent  Entrepreneur  8080401331
#
#         BANK ALLOTMENT  ACCOUNT NO  \
# 4     Access     30000    97421578
# 426  Polaris     50000  1012072626
#
#                                                 REMARK        SECTOR  \
# 4    Beneficiary run a food resturant , amount will...  food canteen
# 426  SHE needs the funds as start up capital for th...   making soap
#
#     YEARS IN BUSINESS SCORE  AMOUNT DECLINE/GRANT
# 4                   5    92  500000           Yes
# 426                 3    63   50000           Yes

# %%
granted2 = full_data.loc[full_data['DECLINE/GRANT'] == 'yes']
granted2
# Out:
#      FORM NO   TITLE      FIRST NAME        MIDDLE NAME       LAST NAME  \
# 1          1     Mrs         Abidemi             Ayinke          Dosumu
# 3          3     Mrs         Risikat          Remilekun         Solanke
# 14        14     Mrs          Muibat              Alaba           Lawal
# 15        15     Mrs       Sopuruchi               Anna            Mbam
# 20        20     MRS      Boluwatife              Ajoke            Sule
# 21        21     Mrs         Ganiyat             Agbeke         Ismaila
# 23        23     Mrs         Fatimoh                NaN            Keye
# 27        27     Mrs        Bilikisu               Wada          Ismail
# 28        28     Mrs          Fatima              Asabe           Shafi
# 30        30     Mrs          Ramota              Alaba           Aruna
# 38        38  Alhaja          Rabiat                 A.          Lawson
# 39        39      Mr         Adeniyi             Hakeem           Yahya
# ...

# %%
granted3 = full_data.loc[full_data['DECLINE/GRANT'] == 'yes ']
granted3
# Out:
#     FORM NO TITLE FIRST NAME MIDDLE NAME LAST NAME        DATE OF BIRTH  \
# 43       43   Mrs   Mopelola      Shadia    Hassan           25/03/1955
# 296     338   Mrs     Zainab   Mosunmola     Ayeni  1989-01-18 00:00:00
#
#                               HOME ADDRESS OCCUPATION    PHONE NO       BANK  \
# 43                         7 Banire street     Trader  8027109379  FirstBank
# 296  17 olufemi street off nathan surulere   business  7032969436        gtb
#
#     ALLOTMENT  ACCOUNT NO                                             REMARK  \
# 43     100000  3015347054                   applicant wants to grow business
# 296    200000    37279425  to be able to be financially stable and self i...
#
#                        SECTOR YEARS IN BUSINESS SCORE  AMOUNT DECLINE/GRANT
# 43   packaging(tapes & sacks)                13    91  100000          yes
# 296         fashion designing                30    85  650000          yes

# %%
granted4 = full_data.loc[full_data['DECLINE/GRANT'] == '`yes']
granted4
# Out:
#     FORM NO TITLE FIRST NAME MIDDLE NAME LAST NAME        DATE OF BIRTH  \
# 281     320   Mrs     Eunice     Abosede  Ekundayo  1965-10-31 00:00:00
#
#                                       HOME ADDRESS OCCUPATION    PHONE NO  \
# 281  3 bamishe close, off daniel along mushin road     trader  8073152839
#
#     BANK ALLOTMENT ACCOUNT NO  \
# 281  ubA     50000  207692335
#
#                                                 REMARK             SECTOR  \
# 281  funds is required to boost her working capital...  footwear and bags
#
#     YEARS IN BUSINESS SCORE  AMOUNT DECLINE/GRANT
# 281                 9    45  200000          `yes

# %%
granted5 = full_data.loc[full_data['DECLINE/GRANT'] == 'grant']
granted5
# Out:
#     FORM NO TITLE FIRST NAME MIDDLE NAME LAST NAME DATE OF BIRTH  \
# 266     293   mrs  Nimotalah     Oyenike   Ibrahim    15/06/1956
#
#                 HOME ADDRESS OCCUPATION    PHONE NO BANK ALLOTMENT  \
# 266  6 jeminatu buraimoh cls     trader  8088805228  uba     50000
#
#         ACCOUNT NO                          REMARK    SECTOR  \
# 266  3470520083789  funds to boost working capital  kerosine
#
#     YEARS IN BUSINESS SCORE  AMOUNT DECLINE/GRANT
# 266                 9    80  400000         grant

# %%
#Total Number of applicants whose application was granted is equal to: 251
len(granted1) + len(granted2) + len(granted3) + len(granted4)+ len(granted5)

# %%
Yes_applicants = pd.concat([granted1, granted2, granted3, granted4, granted5])

# %%
len(Yes_applicants)

# %%
#The total number of applicants not getting the grant = 1056
len(full_data)  - len(Yes_applicants)

# %%
Yes_applicants

# %% [markdown]
# Let's drop the applicant below with missing allotment and amount

# %%
export_csv = full_data.to_csv(r'C:\Users\GETHSEMAN\Desktop\GBAJA2\yes_appliants.csv', 
index = None, header=True)

# %%
#Yes_applicants.drop(['301'], axis  = 0, inplace = True)

# %%
#Yes_applicants[Yes_applicants['AMOUNT'] == 'yes']

# %%
#Yes_applicants['AMOUNT'] = Yes_applicants['AMOUNT'].astype(int)
